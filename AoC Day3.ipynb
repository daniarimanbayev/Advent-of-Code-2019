974,D119,L370,U404,R339,U233,R901,U514,R584,D495,R308,U170,R759,U592,R388,U396,R477,U670,R906,D687,L874,U352,R124,U700,R289,D524,L93,D817,R408,D776,L235,D928,L534,D296,R116,U995,L63,D903,R758,U881,L530,U498,R573,D626,L26,U269,R237,U287,L840,D603,R948,D567,R89,U552,L299,D774,R863,D182,R773,D108,L137,U88,L731,U793,L267,U902,L41,U258,L156,U361,R389,D839,L976,U960,L342,D489,R816,U391,L393,U601,R255,D629,R832,U877,L34,D373,L809,D679,L104,U901,R157,U468,R143,U896,L637,D577,L545,D486,L970,D130,L305,D909,R984,D500,L935,U949,R525,D547,L786,U106,L269,D511,L919"


wire_1_blueprint = puzzle_input_1.split(',')  #splitting inputstr by commas and converting into ints.
wire_2_blueprint = puzzle_input_2.split(',')  #splitting inputstr by commas and converting into ints.


wire_1_horiz_paths = []
wire_1_vert_paths = []
wire_1 = [wire_1_horiz_paths, wire_1_vert_paths]

wire_2_horiz_paths = []
wire_2_vert_paths = []
wire_2 = [wire_2_horiz_paths, wire_2_vert_paths]

placed_wires = []
wire_crosses = []


def wire_path_saver( wire_blueprint, wire_horiz_paths, wire_vert_paths, placed_wires):
    
    wiretip = [0,0]
    
    for movement in wire_blueprint:
        
        direction = movement[0]
        distance = int(movement[1:])
        
        pre_movement_wiretip = [wiretip[0],wiretip[1]]
        
        
        if direction == "U":
            
            #print(pre_movement_wiretip)
            wiretip[1] = wiretip[1] + distance
            #print(pre_movement_wiretip)

            
            wire_vert_paths.append( [wiretip[0], pre_movement_wiretip[1], wiretip[1]] )
            
            if placed_wires:
                            
                for wire in placed_wires:

                    prev_horiz_paths = wire[0]        # all horizontal paths from wire

                    # all horizontal wirepaths from wire that are in the range of y that wiretip has moved
                    possible_wirepaths = [path for path in prev_horiz_paths if ( (path[0] > pre_movement_wiretip[1]) 
                                                                        and (path[0] < wiretip[1]) ) ]

                    # in-range horizontal wirepaths that cross over wiretip's x value
                    crossing_wirepaths = [path for path in possible_wirepaths if ( (path[1] < wiretip[0]) 
                                                                            and (wiretip[0] < path[2]) ) ]

                    for paths in crossing_wirepaths:
                        cross = [wiretip[0], paths[0]]
                        wire_crosses.append(cross)
                
        
        elif direction == "D":
            
            wiretip[1] = wiretip[1] - distance
            
            wire_vert_paths.append( [wiretip[0], wiretip[1], pre_movement_wiretip[1]] )
            
            if placed_wires:
                            
                for wire in placed_wires:

                    prev_horiz_paths = wire[0]        # all horizontal paths from wire

                    # all horizontal wirepaths from wire that are in the range of y that wiretip has moved
                    possible_wirepaths = [path for path in prev_horiz_paths if ( (path[0] > pre_movement_wiretip[1]) 
                                                                        and (path[0] < wiretip[1]) ) ]

                    # in-range horizontal wirepaths that cross over wiretip's x value
                    crossing_wirepaths = [path for path in possible_wirepaths if ( (path[1] < wiretip[0]) 
                                                                            and (wiretip[0] < path[2]) ) ]

                    for paths in crossing_wirepaths:
                        cross = [wiretip[0], paths[0]]
                        wire_crosses.append(cross)
            
        elif direction == "R":
            
            wiretip[0] = wiretip[0] + distance
            
            wire_horiz_paths.append( [wiretip[1], pre_movement_wiretip[0], wiretip[0]] )
            
            if placed_wires:
                            
                for wire in placed_wires:

                    prev_vert_paths = wire[1]        # all vertical paths from wire
                    #print(wire[1])


                    # all vertical wirepaths from wire that are in the range of x that wiretip has moved
                    possible_wirepaths = [path for path in prev_vert_paths if ( (path[0] > pre_movement_wiretip[0]) 
                                                                        and (path[0] < wiretip[0]) ) ]

                    # in-range vertical wirepaths that cross over wiretip's y value
                    crossing_wirepaths = [path for path in possible_wirepaths if ( (path[1] < wiretip[1]) 
                                                                            and (wiretip[1] < path[2]) ) ]

                    for paths in crossing_wirepaths:
                        cross = [paths[0], wiretip[1]]
                        wire_crosses.append(cross)
            
        elif direction == "L":
            
            wiretip[0] = wiretip[0] - distance
            
            wire_horiz_paths.append( [wiretip[1], wiretip[0], pre_movement_wiretip[0]] )
            
            if placed_wires:
                            
                for wire in placed_wires:

                    prev_vert_paths = wire[1]        # all vertical paths from wire
                    #print(wire[1])


                    # all vertical wirepaths from wire that are in the range of x that wiretip has moved
                    possible_wirepaths = [path for path in prev_vert_paths if ( (path[0] > pre_movement_wiretip[0]) 
                                                                        and (path[0] < wiretip[0]) ) ]

                    # in-range vertical wirepaths that cross over wiretip's y value
                    crossing_wirepaths = [path for path in possible_wirepaths if ( (path[1] < wiretip[1]) 
                                                                            and (wiretip[1] < path[2]) ) ]

                    for paths in crossing_wirepaths:
                        cross = [paths[0], wiretip[1]]
                        wire_crosses.append(cross)
            
        else:
            print("direction not found for entry")
            
        

    return



def closest_cross_distance(wire_crosses):
    
    smallest_distance = abs(wire_crosses[0][0]) + abs(wire_crosses[0][1])       # first distance
    
    for cross in wire_crosses:
        
        smallest_distance = min( smallest_distance, abs(cross[0])+abs(cross[1]) )
    
    return smallest_distance



wire_path_saver(wire_1_blueprint, wire_1_horiz_paths, wire_1_vert_paths, [])
wire_1_horiz_paths.sort( key=lambda x: int(x[0]) )
wire_1_vert_paths.sort( key=lambda x: int(x[0]) )
#print(wire_1[1])
placed_wires.append(wire_1)
#print(placed_wires)

wire_path_saver(wire_2_blueprint, wire_2_horiz_paths, wire_2_vert_paths, placed_wires)

print(wire_1)

#print(wire_crosses)
print(closest_cross_distance(wire_crosses))
        
    



    
    

    




# comments
# 4 directions prefixes: each direction prefix
# 2 cardinal directions: L is - and R is + in x, D is - and U is + in y.
# what matters is that both 1 and 2 have equal x and y at some points, detecting those locations, and finding the minimum of those

# maybe save each point in space that wire_1 passes through in a list, and constantly compare for equivalence with wire_2?

# if wire_2 goes down from point A_2 to point B_2, and that difference encapsulates wire_1's point A_1, 
# and wire_1's going left from point A_1 to point B_1 encapsulates wire_2's point A_2, then we have a cross
# We take wire_1's y position and wire_2's x position, since wire_1 was moving laterally and wire_2 moving vertically
# only problem is, there's no guarantee that wire_2's movement from A_2 to B_2 happens on the same time as wire_1's A_1 to B_1

# we need to keep a list of paths made by wire_1 and wire_2 (can wires cross themselves?)
# there are two cases when there'd be a cross: when one wire already has made a path, and another encounters it
# or when they both encounter/make a path at the same time that crosses. The paragraph above seems like it can handle that situation.
# list for wire_1 might actually be two lists: all vertical paths and all horizontal paths
# (when wire_2 is moving vertically, it checks against all wire_1's horizontal paths) (does it have to be ALL of its paths?)
# So for example wire_1's list of horizontal paths might be a list of triplets: [height_y, start_x, end_x]
# when wire_2 is moving vertically from A_2 to B_2, it checks in wire_1's horionztal_paths list for paths with y between A_2 and B_2.
# *** I'm assuming that the problem doesn't have wires overlapping, only crossing. 

# So there'll be 4 running lists: wire_1_horiz_paths, wire_1_vert_paths, wire_2_horiz_paths, wire_2_vert_paths.
# cross resolution will be handled like in above paragraph.
# and a list of crosses that contains x,y coords of all crosses found.
# solution would just be the smallest of x,y, coords (abs value of x,y and add them, return the cross with smallest.)


# we also will have variable (lists) wire_1_tip and wire_2_tip that are the tips of each respective wire, udpated with each additional movement

# parsing the string:
# we go through
# wires may have different lengths, so

# rethinking, instead of iterating through both wires at the same time, it might be better to just add one wire at a time.
# simplifies process, and makes it feasible/scalable for possibly more wires in the future.
# therefore there's only one case when there'd be a cross: wire already made a path, and next wire is crossing it. (no time involved)
# Out:
# [[[-7914, 1180, 2076], [-7714, 621, 735], [-7497, 1402, 1501], [-7323, -107, 621], [-7308, 735, 1125], [-7254, -968, -957], [-7234, -957, -249], [-7134, 1103, 1180], [-7078, 1501, 2076], [-7016, -1049, -249], [-6935, -563, -355], [-6914, 926, 1402], [-6738, -1237, -989], [-6605, -449, -8], [-6517, 926, 1125], [-6493, -1522, -1374], [-6479, -113, -107], [-6405, -8, 450], [-6384, -1099, -989], [-6335, -1489, -563], [-6302, -968, -564], [-6266, -1049, -113], [-6212, -355, 450], [-6173, -673, -506], [-6170, 1103, 1544], [-6058, 2434, 3255], [-6002, 885, 1460], [-5993, -1136, -1099], [-5932, -1374, -449], [-5904, -1237, -829], [-5889, -1522, -1075], [-5858, 885, 1272], [-5832, -506, -460], [-5794, 1942, 2445], [-5721, -1489, -829], [-5711, 2280, 2319], [-5622, 1791, 1948], [-5617, 1792, 2319], [-5581, 3229, 4014], [-5556, -673, 185], [-5447, 1544, 1792], [-5443, 2547, 3229], [-5440, 2087, 2258], [-5394, -1423, -1136], [-5366, -1423, -564], [-5352, 2573, 3024], [-5339, 1083, 1272], [-5320,
# ...

# %%
import numpy as np
import math
import bisect


puzzle_input_1 = "R998,U547,L703,D251,L776,U837,R100,U240,R197,D216,L220,U606,L437,U56,R940,U800,L968,D464,L870,D797,L545,D824,R790,U5,R347,D794,R204,U538,L247,U385,L103,D260,L590,U813,L549,U309,L550,U321,R862,D686,R368,D991,R451,D836,R264,D138,L292,D319,L784,D369,R849,U865,R776,D726,R223,D118,L790,D208,L836,D592,R310,D36,R991,U674,L205,U407,R422,U350,L126,D320,L239,U353,L509,U48,R521,D544,L157,D551,R614,D493,R407,D965,R498,U248,R826,U573,L782,D589,R616,D992,L806,D
wire_1_blueprint = puzzle_input_1.split(',')  #splitting inputstr by commas and converting into ints.
wire_2_blueprint = puzzle_input_2.split(',')  #splitting inputstr by commas and converting into ints.


wire_1_horiz_paths = []
wire_1_vert_paths = []
wire_1 = [wire_1_horiz_paths, wire_1_vert_paths]

wire_2_horiz_paths = []
wire_2_vert_paths = []
wire_2 = [wire_2_horiz_paths, wire_2_vert_paths]

placed_wires = []
wire_crosses = []


def wire_path_saver( wire_blueprint, wire_horiz_paths, wire_vert_paths, placed_wires):
    
    wiretip = [0,0]
        
    for count,movement in enumerate(wire_blueprint):
        direction = movement[0]
        distance = int(movement[1:])
        
        pre_movement_wiretip = [wiretip[0],wiretip[1]]
        
        
        if direction == "U":
            
            #print(pre_movement_wiretip)
            wiretip[1] = wiretip[1] + distance
            #print(pre_movement_wiretip)

            
            wire_vert_paths.append( [wiretip[0], pre_movement_wiretip[1], wiretip[1], count] )
            
            if placed_wires:
                            
                for wire in placed_wires:

                    prev_horiz_paths = wire[0]        # all horizontal paths from wire

                    # all horizontal wirepaths from wire that are in the range of y that wiretip has moved
                    possible_wirepaths = [path for path in prev_horiz_paths if ( (path[0] > pre_movement_wiretip[1]) and (path[0] < wiretip[1]) ) ]

                    # in-range horizontal wirepaths that cross over wiretip's x value
                    crossing_wirepaths = [path for path in possible_wirepaths if ( (path[1] < wiretip[0]) and (wiretip[0] < path[2]) ) ]

                    for paths in crossing_wirepaths:
                        
                        count1 = count      # current wire's movements taken
                        count2 = paths[3]   # previous wire's movements taken
                        
                        cross = [wiretip[0], paths[0], count1, count2]
                        wire_crosses.append(cross)
                
        
        elif direction == "D":
            
            wiretip[1] = wiretip[1] - distance
            
            wire_vert_paths.append( [wiretip[0], wiretip[1], pre_movement_wiretip[1], count] )
            
            if placed_wires:
                            
                for wire in placed_wires:

                    prev_horiz_paths = wire[0]        # all horizontal paths from wire

                    # all horizontal wirepaths from wire that are in the range of y that wiretip has moved
                    possible_wirepaths = [path for path in prev_horiz_paths if ( (path[0] < pre_movement_wiretip[1]) and (path[0] > wiretip[1]) ) ]

                    # in-range horizontal wirepaths that cross over wiretip's x value
                    crossing_wirepaths = [path for path in possible_wirepaths if ( (path[1] < wiretip[0]) and (wiretip[0] < path[2]) ) ]

                    for paths in crossing_wirepaths:
                        
                        count1 = count      # current wire's movements taken
                        count2 = paths[3]   # previous wire's movements taken
                        
                        cross = [wiretip[0], paths[0], count1, count2]
                        wire_crosses.append(cross)
            
        elif direction == "R":
            
            wiretip[0] = wiretip[0] + distance
            
            wire_horiz_paths.append( [wiretip[1], pre_movement_wiretip[0], wiretip[0], count] )
            
            if placed_wires:
                            
                for wire in placed_wires:

                    prev_vert_paths = wire[1]        # all vertical paths from wire
                    #print(wire[1])

                    # all vertical wirepaths from wire that are in the range of x that wiretip has moved
                    possible_wirepaths = [path for path in prev_vert_paths if ( (path[0] > pre_movement_wiretip[0]) and (path[0] < wiretip[0]) ) ]

                    # in-range vertical wirepaths that cross over wiretip's y value
                    crossing_wirepaths = [path for path in possible_wirepaths if ( (path[1] < wiretip[1])  and (wiretip[1] < path[2]) ) ]

                    for paths in crossing_wirepaths:
                        
                        count1 = count      # current wire's movements taken
                        count2 = paths[3]   # previous wire's movements taken
                        
                        cross = [paths[0], wiretip[1], count1, count2]
                        wire_crosses.append(cross)
            
        elif direction == "L":
            
            wiretip[0] = wiretip[0] - distance
            
            wire_horiz_paths.append( [wiretip[1], wiretip[0], pre_movement_wiretip[0], count] )
            
            if placed_wires:
                            
                for wire in placed_wires:

                    prev_vert_paths = wire[1]        # all vertical paths from wire
                    #print(wire[1])


                    # all vertical wirepaths from wire that are in the range of x that wiretip has moved
                    possible_wirepaths = [path for path in prev_vert_paths if ( (path[0] < pre_movement_wiretip[0]) 
                                                                        and (path[0] > wiretip[0]) ) ]

                    # in-range vertical wirepaths that cross over wiretip's y value
                    crossing_wirepaths = [path for path in possible_wirepaths if ( (path[1] < wiretip[1]) 
                                                                            and (wiretip[1] < path[2]) ) ]

                    for paths in crossing_wirepaths:
                        
                        count1 = count      # current wire's movements taken
                        count2 = paths[3]   # previous wire's movements taken
                        
                        
                        cross = [paths[0], wiretip[1], count1, count2]
                        wire_crosses.append(cross)
            
        else:
            print("direction not found for entry")
            
        

    return



def closest_cross_distance(wire_crosses):
    
    smallest_distance = abs(wire_crosses[0][0]) + abs(wire_crosses[0][1])       # first distance
    
    for cross in wire_crosses:
        
        smallest_distance = min( smallest_distance, abs(cross[0])+abs(cross[1]) )
    
    return smallest_distance





def minimal_wire_steps(wire_crosses, wire_1, wire_2):
    
    cross_wiresteps = []
    
    
    for cross in wire_crosses:
#        print(wire_1[0])
#        print(wire_1[0][:cross[3]])
#        print(cross[3])
#        print(wire_1[0][:cross[3]][3])

        distance_path1 = 0
        
        #print(wire_1[0])
        
        #print(wire_1[0][:cross[3]])
        
        for movement in wire_1[0][:cross[3]]:
            distance_path1 = distance_path1 + abs(movement[2] - movement[1])
            if movement[3] == cross[3]:
                wire1_lastmovement = movement
                
        for movement in wire_1[1][:cross[3]]:
            distance_path1 = distance_path1 + abs(movement[2] - movement[1])
            if movement[3] == cross[3]:
                wire1_lastmovement = movement
        if(cross[3] == 0):                
            distance_path1 = 0
            wire1_lastmovement = [0,0,0,0]
            
        #distance_path2 = 0
        
        #print(wire_2[0])
        #print(cross[2])
        #print(wire_2[0][:cross[2]])

                
        for movement in wire_2[0][:cross[2]]:
            distance_path2 = distance_path2 + abs(movement[2] - movement[1])
#            print(movement)
            if movement[3] == cross[2]:
                wire2_lastmovement = movement
                
        for movement in wire_2[1][:cross[2]]:
            distance_path2 = distance_path2 + abs(movement[2] - movement[1])
            if movement[3] == cross[2]:
                wire2_lastmovement = movement
        if(cross[2] == 0):
            distance_path2 = 0
            wire2_lastmovement = [0,0,0,0]
            
        
        if ((wire1_lastmovement[0] == cross[0]) or (wire1_lastmovement[2] == cross[1])):
            wire1_lastpoint = [wire1_lastmovement[0], wire1_lastmovement[2]]
        else:
            wire1_lastpoint = [wire1_lastmovement[0], wire1_lastmovement[1]]
        
        if ((wire2_lastmovement[0] == cross[0]) or (wire2_lastmovement[2] == cross[1])):
            wire2_lastpoint = [wire2_lastmovement[0], wire2_lastmovement[2]]
        else:
            wire2_lastpoint = [wire2_lastmovement[0], wire2_lastmovement[1]]

        
        last_wire1_movement = max(abs(cross[1] - wire1_lastpoint[1]), abs(cross[0] - wire1_lastpoint[0]))
        
        last_wire2_movement = max(abs(cross[1] - wire2_lastpoint[1]), abs(cross[0] - wire2_lastpoint[0]))
        
        print([distance_path1, distance_path2, last_wire1_movement, last_wire2_movement])
        
        totaldistance = sum([distance_path1, distance_path2, last_wire1_movement, last_wire2_movement])
        
        cross_wiresteps.append(totaldistance)
        
#        smallest_steps = min()

    print(cross_wiresteps)
    
    print(min(cross_wiresteps))
    
    
     #smallest_steps



wire_path_saver(wire_1_blueprint, wire_1_horiz_paths, wire_1_vert_paths, [])
#wire_1_horiz_paths.sort( key=lambda x: int(x[0]) )
#wire_1_vert_paths.sort( key=lambda x: int(x[0]) )
#print(wire_1[1])
placed_wires.append(wire_1)
#print(placed_wires)

wire_path_saver(wire_2_blueprint, wire_2_horiz_paths, wire_2_vert_paths, placed_wires)

#print(wire_crosses)
print(closest_cross_distance(wire_crosses))

#print(wire_1[0])
#print(wire_1[1])

minimal_wire_steps(wire_crosses, wire_1, wire_2 )
# Out:
# 731
# [28773, 0, 283, 943]
# [28773, 2059, 161, 1117]
# [4865, 6504, 541, 1115]
# [16065, 20548, 3488, 439]
# [19197, 38626, 244, 3717]
# [19197, 58157, 86, 3875]
# [13187, 84285, 2604, 215]
# [15070, 110413, 2660, 159]
# [4865, 138160, 804, 894]
# [6184, 166811, 103, 2202]
# [9356, 195462, 103, 2202]
# [12392, 224113, 493, 2202]
# [4865, 253987, 391, 1674]
# [4452, 285187, 777, 446]
# [4452, 317773, 777, 230]
# [4865, 350973, 607, 1553]
# [6184, 386329, 11, 2389]
# [12392, 421685, 401, 2389]
# [7924, 458172, 1754, 665]
# [15070, 494659, 2660, 219]
# [15702, 532455, 581, 2237]
# [29999, 32110, 13025, 40540, 61784, 81315, 100291, 128302, 144723, 175300, 207123, 239200, 260917, 290862, 323232, 357998, 394913, 436867, 468515, 512608, 550975]
# 13025

# %%
# credit to u/floriankl on /r/adventofcode for solution


def process_wire(instr_line):
    current_pos = [0, 0]
    for instr in instr_line.split(','):
        for _ in range(int(instr[1:])):
            current_pos[0 if instr[0] in ('L', 'R') else 1] += -1 if instr[0] in ('L', 'D') else 1
            yield tuple(current_pos)
with open('day3_wires.txt', 'r') as f:
    wires = [list(process_wire(line)) for line in f.readlines()]
intersections = set(wires[0]) & set(wires[1])
print(min(abs(x)+abs(y) for (x, y) in intersections)) #Part 1
print(2 + min(sum(wire.index(intersect) for wire in wires) for intersect in intersections)) #Part 2
# Out:
# 731
# 5672
